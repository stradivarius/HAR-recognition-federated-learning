# %%
import pandas as pd
import pathlib
import numpy as np
import flwr as fl
from flwr.common import NDArrays, Scalar, Metrics
from typing import Dict, Tuple, List
from sklearn.metrics import classification_report
from pprint import pprint
from minisom import MiniSom

SOM_DIM = 20
SOM_NUM_ITER = 100
SUBJECTS_NUMBER = 30
FED_ROUNDS = 5

prefix_train = pathlib.Path("UCI HAR Dataset split/train")
prefix_test = pathlib.Path("UCI HAR Dataset split/test")

# %%
def som_predict(som, Xtrain, ytrain, Xtest, ytest):
    # Test the SOM

    print( Xtrain.shape, ytrain.shape, Xtest.shape, ytest.shape)
    
    # Find the association between neurons and class
    winmap = som.labels_map(Xtrain , ytrain.flatten()) 
    default_class = np.sum( list (winmap.values())).most_common()[0][0] # The most common class in the dataset (when we are undecided)

    # Test
    prediction = []
    for test_sample in Xtest:
        win_position = som.winner(test_sample)
        if win_position in winmap:
            prediction.append( winmap [ win_position ].most_common()[0][0])
        else:
            prediction.append(default_class) #FIXME take the neighboring

    report = classification_report(
            ytest.flatten(),
            prediction,
            zero_division=0.0,
            output_dict=True,
    )

    # Eval Accuracy
    pprint ( report )

    return {"accuracy": float(report["accuracy"])}

# %%
class SomClient(fl.client.NumPyClient):
    def __init__(self, som, Xtrain, ytrain, Xtest, ytest, train_iter, cid):
        self.som = som
        self.Xtrain = Xtrain
        self.ytrain = ytrain.flatten()
        self.train_iter = train_iter
        self.Xtest = Xtest
        self.ytest = ytest.flatten()
        self.cid = cid

    # Return the current local model parameters
    def get_parameters(self, config) -> NDArrays:
        return [self.som.get_weights()]
    
    def set_parameters(self, parameters):
        self.som._weights = parameters
    
    # Receive model parameters from the server, 
    # train the model parameters on the local data, 
    # and return the (updated) model parameters to the server
    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.som.train_random(self.Xtrain, self.train_iter, verbose=False)
        return self.get_parameters(), len(self.Xtrain), {}
    
    # Receive model parameters from the server,
    # evaluate the model parameters on the local data, 
    # and return the evaluation result to the server
    def evaluate(self, parameters, config) -> Tuple[float, int, Dict[str, Scalar]]:
        self.set_parameters(parameters)

        return float(0), len(self.Xtest), som_predict(self.som, self.Xtrain, self.ytrain, self.Xtest, self.ytest)

# %%
def load_df(glob : str, path : pathlib.Path, subject = -1, avoid = -1) -> pd.DataFrame: # idx must be a int TODO
    _df = pd.DataFrame()
    for idx, fn in enumerate(path.glob(f'**/{glob}.csv')):
            if subject in (-1, idx) and idx != avoid: 
                _df = pd.concat([_df, pd.read_csv(fn, sep=' ',header = None)], ignore_index = True)
    return _df

# %%
train_x_df = load_df('Xtrain', prefix_train, subject = -1, avoid = 23).to_numpy()
train_y_df = load_df('ytrain', prefix_train, subject = -1, avoid = 23).to_numpy()

test_x_df = load_df('Xtest', prefix_test, subject = 23).to_numpy()
test_y_df = load_df('ytest', prefix_test, subject = 23).to_numpy()

# %%
def weighted_simple_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    # Multiply accuracy of each client by number of examples used
    w_accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]
    s_accuracies = [m["accuracy"] for _, m in metrics]
    clients_num = len(metrics)
    # Aggregate and return custom metric (weighted average)
    return {"w_accuracy": sum(w_accuracies) / sum(examples), "s_accuracy": sum(s_accuracies)/clients_num}

def simple_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    s_accuracies = [m["accuracy"] for _, m in metrics]
    clients_num = len(metrics)
    # Aggregate and return custom metric (weighted average)
    return {"accuracy": sum(s_accuracies)/clients_num}

# %%
def spawn_client(cid) -> SomClient:

    # prendo il dataset corrispondente al cid(client id)
    _Xtrain = load_df('Xtrain', prefix_train, subject = cid).to_numpy()
    _ytrain = load_df('ytrain', prefix_train, subject = cid).to_numpy()

    _Xtest = load_df('Xtest', prefix_test, subject = cid).to_numpy()
    _ytest = load_df('ytest', prefix_test, subject = cid).to_numpy()

    som = MiniSom(
            SOM_DIM,
            SOM_DIM,
            _Xtrain.shape[1],
            sigma=5,
            learning_rate=0.1,
            neighborhood_function="gaussian",
            activation_distance="manhattan",
        )

    return SomClient(som, _Xtrain, _ytrain, _Xtest, _ytest, SOM_NUM_ITER, cid)

# %%
def train_federated(num_rounds):

   strategy = fl.server.strategy.FedAvg(
       fraction_fit=1.0,
       fraction_evaluate=1.0,
       min_fit_clients=int(SUBJECTS_NUMBER),
       min_evaluate_clients=int(SUBJECTS_NUMBER),
       min_available_clients=int(SUBJECTS_NUMBER),
       evaluate_metrics_aggregation_fn=simple_average,
   )
   client_resources = None
   hist = fl.simulation.start_simulation(
       client_fn = spawn_client,
       num_clients = int(SUBJECTS_NUMBER),
       config = fl.server.ServerConfig(num_rounds=num_rounds),
       strategy = strategy,
       client_resources = client_resources,
   )
   #    ray_init_args = {"num_cpus": 2, "num_gpus":0.0}
   return hist.metrics_distributed

# %%
# Train the SOM


som = MiniSom(
        SOM_DIM,
        SOM_DIM,
        train_x_df.shape[1], #Number of Features
        sigma = 5,
        learning_rate = 0.1,
        neighborhood_function = "gaussian",
        activation_distance = "manhattan",
    )

som.random_weights_init(train_x_df)
som.train_random(train_x_df, SOM_NUM_ITER, verbose=False)  # random training

# %%
# Test the SOM
som_predict(som, train_x_df, train_y_df, test_x_df, test_y_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_21769/3187159626.py in <module>
#       1 # Test the SOM
# ----> 2 som_predict(som, train_x_df, train_y_df, test_x_df, test_y_df)
#
# /tmp/ipykernel_21769/3170904944.py in som_predict(som, Xtrain, ytrain, Xtest, ytest)
#       2     # Test the SOM
#       3
# ----> 4     print( Xtrain.shape(), ytrain.shape(), Xtest.shape(), ytest.shape())
#       5
#       6     # Find the association between neurons and class
#
# TypeError: 'tuple' object is not callable

# %%
accs_fed = train_federated(5)
accs_fed
# Out:
# INFO flwr 2023-11-07 17:34:00,332 | app.py:175 | Starting Flower simulation, config: ServerConfig(num_rounds=5, round_timeout=None)
# 2023-11-07 17:34:02,413	INFO worker.py:1673 -- Started a local Ray instance.
# INFO flwr 2023-11-07 17:34:04,708 | app.py:210 | Flower VCE: Ray initialized with resources: {'CPU': 8.0, 'object_store_memory': 1797567283.0, 'memory': 3595134567.0, 'node:__internal_head__': 1.0, 'node:130.136.2.167': 1.0}
# INFO flwr 2023-11-07 17:34:04,709 | app.py:218 | No `client_resources` specified. Using minimal resources for clients.
# INFO flwr 2023-11-07 17:34:04,710 | app.py:224 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO flwr 2023-11-07 17:34:04,736 | app.py:270 | Flower VCE: Creating VirtualClientEngineActorPool with 8 actors
# INFO flwr 2023-11-07 17:34:04,738 | server.py:89 | Initializing global parameters
# INFO flwr 2023-11-07 17:34:04,740 | server.py:276 | Requesting initial parameters from one random client
# INFO flwr 2023-11-07 17:34:08,122 | server.py:280 | Received initial parameters from one random client
# INFO flwr 2023-11-07 17:34:08,124 | server.py:91 | Evaluating initial parameters
# INFO flwr 2023-11-07 17:34:08,126 | server.py:104 | FL starting
# DEBUG flwr 2023-11-07 17:34:08,128 | server.py:222 | fit_round 1: strategy sampled 30 clients (out of 30)
# ERROR flwr 2023-11-07 17:34:08,253 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/worker.py", line 2563, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 22 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
#
# ERROR flwr 2023-11-07 17:34:08,265 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 22 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
# ERROR flwr 2023-11-07 17:34:08,316 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/worker.py", line 2563, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 1 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
#
# ERROR flwr 2023-11-07 17:34:08,319 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 1 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
# ERROR flwr 2023-11-07 17:34:08,421 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/worker.py", line 2563, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 0 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
#
# ERROR flwr 2023-11-07 17:34:08,423 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 0 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
# ERROR flwr 2023-11-07 17:34:08,473 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/worker.py", line 2563, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 26 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
#
# ERROR flwr 2023-11-07 17:34:08,478 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 26 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
# ERROR flwr 2023-11-07 17:34:08,528 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/worker.py", line 2563, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 23 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
#
# ERROR flwr 2023-11-07 17:34:08,533 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 23 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
# ERROR flwr 2023-11-07 17:34:08,578 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/worker.py", line 2563, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 12 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
#
# ERROR flwr 2023-11-07 17:34:08,580 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 12 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
# ERROR flwr 2023-11-07 17:34:08,614 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/worker.py", line 2563, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 23, in fit
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random
#     self.train(data, num_iteration, random_order=True, verbose=verbose)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 11 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 23, in fit\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 450, in train_random\n    self.train(data, num_iteration, random_order=True, verbose=verbose)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 415, in train\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
#
# ERROR flwr 2023-11-07 17:34:08,617 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=22112, ip=130.136.2.167, actor_id=4a852b5bdd0a43fa722f19dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f77e60955b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
# ...
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ray/_private/worker.py", line 2563, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=22108, ip=130.136.2.167, actor_id=31d44a7b0e4c5bf9dcfee35f01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f535e401610>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 32, in evaluate
#   File "/tmp/ipykernel_21769/3079251016.py", line 5, in som_predict
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 623, in labels_map
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22108, ip=130.136.2.167, actor_id=31d44a7b0e4c5bf9dcfee35f01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f535e401610>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 9 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 32, in evaluate\n  File "/tmp/ipykernel_21769/3079251016.py", line 5, in som_predict\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 623, in labels_map\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
#
# ERROR flwr 2023-11-07 17:34:15,245 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=22104, ip=130.136.2.167, actor_id=108ffc51cf38ffcdb527913d01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7fbad8dcc610>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 32, in evaluate
#   File "/tmp/ipykernel_21769/3079251016.py", line 5, in som_predict
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 623, in labels_map
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22104, ip=130.136.2.167, actor_id=108ffc51cf38ffcdb527913d01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7fbad8dcc610>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 15 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 32, in evaluate\n  File "/tmp/ipykernel_21769/3079251016.py", line 5, in som_predict\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 623, in labels_map\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
# ERROR flwr 2023-11-07 17:34:15,247 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=22111, ip=130.136.2.167, actor_id=99627470d52248aff9acba4201000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f6e1023f550>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 32, in evaluate
#   File "/tmp/ipykernel_21769/3079251016.py", line 5, in som_predict
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 623, in labels_map
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22111, ip=130.136.2.167, actor_id=99627470d52248aff9acba4201000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f6e1023f550>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 11 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 32, in evaluate\n  File "/tmp/ipykernel_21769/3079251016.py", line 5, in som_predict\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 623, in labels_map\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
# ERROR flwr 2023-11-07 17:34:15,248 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=22109, ip=130.136.2.167, actor_id=cec0476d4bf9c085a3d8ac4101000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f5b997405b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 32, in evaluate
#   File "/tmp/ipykernel_21769/3079251016.py", line 5, in som_predict
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 623, in labels_map
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22109, ip=130.136.2.167, actor_id=cec0476d4bf9c085a3d8ac4101000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f5b997405b0>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 12 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 32, in evaluate\n  File "/tmp/ipykernel_21769/3079251016.py", line 5, in som_predict\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 623, in labels_map\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
# ERROR flwr 2023-11-07 17:34:15,252 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=22108, ip=130.136.2.167, actor_id=31d44a7b0e4c5bf9dcfee35f01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f535e401610>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#   File "/tmp/ipykernel_21769/621517024.py", line 32, in evaluate
#   File "/tmp/ipykernel_21769/3079251016.py", line 5, in som_predict
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 623, in labels_map
#     self._check_input_len(data)
#   File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len
#     data_len = len(data[0])
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=22108, ip=130.136.2.167, actor_id=31d44a7b0e4c5bf9dcfee35f01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x7f535e401610>)
#   File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 9 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_actor.py", line 60, in run\n    job_results = job_fn()\n  File "/usr/local/lib/python3.8/dist-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n  File "/usr/local/lib/python3.8/dist-packages/flwr/client/app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n  File "/tmp/ipykernel_21769/621517024.py", line 32, in evaluate\n  File "/tmp/ipykernel_21769/3079251016.py", line 5, in som_predict\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 623, in labels_map\n    self._check_input_len(data)\n  File "/usr/local/lib/python3.8/dist-packages/minisom.py", line 308, in _check_input_len\n    data_len = len(data[0])\nIndexError: index 0 is out of bounds for axis 0 with size 0\n',)
# DEBUG flwr 2023-11-07 17:34:15,259 | server.py:187 | evaluate_round 5 received 0 results and 30 failures
# INFO flwr 2023-11-07 17:34:15,261 | server.py:153 | FL finished in 7.1329876740019245
# INFO flwr 2023-11-07 17:34:15,263 | app.py:225 | app_fit: losses_distributed []
# INFO flwr 2023-11-07 17:34:15,264 | app.py:226 | app_fit: metrics_distributed_fit {}
# INFO flwr 2023-11-07 17:34:15,265 | app.py:227 | app_fit: metrics_distributed {}
# INFO flwr 2023-11-07 17:34:15,266 | app.py:228 | app_fit: losses_centralized []
# INFO flwr 2023-11-07 17:34:15,268 | app.py:229 | app_fit: metrics_centralized {}
# {}
